# %%
nombre = "Federico"
edad = 45

# %%
nombre = "Pedro"

# %% [markdown]
# Lo que sige es una funcion

# %%
print(nombre)
# Out:
# Pedro

# %%
def  mostrar_nombre(persona):
  print(f'Adios {persona}')

# %%
mostrar_nombre("Milena")
# Out:
# Hola Milena
